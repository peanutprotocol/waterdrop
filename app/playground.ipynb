# %%
import pandas as pd

# load addresses.csv
addresses = pd.read_csv("data/addresses.csv")

# first column to list
addresses_list = addresses.iloc[:, 0].tolist()
addresses_list
# Out:
# ['GENESIS',
#  '0x1bdae8d8c66badc1d02fe9f58e1586fb00d21b87',
#  '0x31b98d14007bdee637298086988a0bbd31184523',
#  '0x18a3462427bcc9133bb46e88bcbe39cd7ef0e761',
#  '0x78c115f1c8b7d0804fbdf3cf7995b030c512ee78',
#  '0x1464d4e3c815de3028572b850c6c34dfc57e9320',
#  '0x4d496ccc28058b1d74b7a19541663e21154f9c84',
#  '0x8c1e1e5b47980d214965f3bd8ea34c413e120ae4',
#  '0xe0a2bd4258d2768837baa26a28fe71dc079f84c7',
#  '0x10f5d45854e038071485ac9e402308cf80d2d2fe',
#  '0x382b4ca2c4a7cd28c1c400c69d81ec2b2637f7dd',
#  '0x75cf915fe0a5727ef5befcb117f7659f02e64a1c',
#  '0x6cc9397c3b38739dacbfaa68ead5f5d77ba5f455',
#  '0x03801efb0efe2a25ede5dd3a003ae880c0292e4d',
#  '0xcfe95817ac44c3f8ce75f1ee6ec1431f586ab5a3',
#  '0xcb26b78450c9a6585492434acbc854e36b384c8c',
#  '0x874437b5a42aa6e6419ec2447c9e36c278c46532',
#  '0xc8e924510f8dab87cd53c4aeffde0ab4df5a87b8',
#  '0xf8561dc64e577b0cf53dd3fc11329e80b1a8343e',
#  '0x8a2f72e86eb3b4a336d09b099f83a4255ef21d25',
#  '0x8c39e02d1e1192d754646de1d6b9c59ca01241b2',
# ...
